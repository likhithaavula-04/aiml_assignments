# %%
#load of libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
# Dataframe attributes
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
# Drop Duplicate column( Temp C) and Unnames column


data1 = data.drop(['Unnamed: 0', "Temp C"], axis =1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#Convert the month column  data type to float datatype
data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
# Drop duplicated rows
data1.drop_duplicates(keep='first')
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.drop_duplicates(keep='first', inplace = True)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.rename({'Solar.R': 'Solar'}, axis=1, inplace = True)
data1
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 11.0+ KB

# %%
data1.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols = data1.columns
colors = ['black', 'yellow']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors),cbar = True)
# Out:
# <Axes: >

# %%
cols = data1.columns
colors = ['white', 'pink']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors),cbar = True)
# Out:
# <Axes: >

# %%
cols = data1.columns
colors = ['pink', 'green', 'white']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors),cbar = True)
# Out:
# <Axes: >

# %%
median_ozone = data1["Ozone"].median()
mean_ozone = data1["Ozone"].mean()
print("Median of Ozone: ",median_ozone)
print("Mean of Ozone: ", mean_ozone)
# Out:
# Median of Ozone:  31.0
# Mean of Ozone:  41.81512605042017

# %%
data1['Ozone'] = data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
median_solar = data1["Solar"].median()
mean_solar = data1["Solar"].mean()
print("Median of Solar: ",median_solar)
print("Mean of Solar: ", mean_solar)
# Out:
# Median of Solar:  199.0
# Mean of Solar:  185.36666666666667

# %%
data1['Solar'] = data1['Solar'].fillna(median_solar)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
data1['Solar'] = data1['Solar'].fillna(mean_solar)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
data1.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4    5.0    1  2010    67       S
# 1   36.0  118.0   8.0    5.0    2  2010    72       C
# 2   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3   18.0  313.0  11.5    5.0    4  2010    62       S
# 4   31.0  199.0  14.3    5.0    5  2010    56       S

# %%
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
print(data1["Month"].value_counts())
mode_month = data1["Month"].mode()[0]
print(mode_month)
# Out:
# Month
# 9.0    33
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data1["Month"] = data1["Month"].fillna(mode_month)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
data1.reset_index(drop=True)
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4     31.0  199.0  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155   31.0  145.0  13.2    9.0   27  2010    77       S
# 156   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# ### Detection of outliers in the columns

# %% [markdown]
# ### Method1: Using histograms and box plots

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
sns.boxplot(data=data1["Ozone"], ax=axes[0], color='skyblue', width=0.5, orient = 'h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data1["Ozone"], kde=True, ax=axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
sns.boxplot(data=data1["Ozone"], ax=axes[0], color='yellow', width=0.5, orient = 'v')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data1["Ozone"], kde=True, ax=axes[1], color='green', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
sns.boxplot(data=data1["Ozone"], ax=axes[0], color='black', width=0.5, orient = 'h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data1["Ozone"], kde=True, ax=axes[1], color='blue', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
sns.boxplot(data=data1["Ozone"], ax=axes[0], color='black', width=0.5, orient = 'v')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data1["Ozone"], kde=True, ax=axes[1], color='red', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations
#  - The ozone column has extreme values beyond 81 as seen from box plot
#  - The same is confirmed from the below right=skewed histogram

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
sns.boxplot(data=data1["Solar"], ax=axes[0], color='black', width=0.5, orient = 'v')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Solar Levels")
sns.histplot(data1["Solar"], kde=True, ax=axes[1], color='brown', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Solar Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
sns.violinplot(data=data1["Ozone"], color='black')
# Out:
# <Axes: ylabel='Ozone'>

# %%
sns.violinplot(data=data1["Solar"], color='lavender')
# Out:
# <Axes: ylabel='Solar'>

# %%
sns.violinplot(data=data1["Month"], color='yellow')
# Out:
# <Axes: ylabel='Month'>

# %%
sns.violinplot(data=data1["Weather"], color='green')
# Out:
# <Axes: ylabel='Weather'>

# %%
sns.violinplot(data=data1["Temp"], color='brown')
# Out:
# <Axes: ylabel='Temp'>

# %%
sns.violinplot(data=data1["Year"], color='brown')
# Out:
# <Axes: ylabel='Year'>

# %%
sns.violinplot(data=data1["Ozone"], color='black')
plt.title("Violin plot")
plt.show()

# %%
plt.boxplot(data1["Ozone"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d22e598dd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d22e5aea20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d22e5ae360>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d22e5aefc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d22e5af290>],
#  'means': []}

# %%
plt.figure(figsize=(6,2))
boxplot_data = plt.boxplot(data1["Ozone"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %% [markdown]
# ### Method 2
# - Using mu +/-3*sigma limits

# %%
data1["Ozone"].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]

for x in data1["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\likhi\AppData\Local\Temp\ipykernel_19896\3121128980.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# C:\Users\likhi\AppData\Local\Temp\ipykernel_19896\3121128980.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %% [markdown]
# ### Quantile-Quantile plot for detection of outliers

# %%
import scipy.stats as stats
plt.figure(figsize=(8, 6))
stats.probplot(data1["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q Plot for Outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# ### Observations from Q-Q plot
# - The data does not follow normal distribution as the points are deviating significantly away from
# - The data shows a rifht-skewed distribution and possible outliers

# %%
sns.violinplot(data=data1["Ozone"], color='lightgreen')
plt.title("Violin Plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.violinplot(data=data1, x = "Weather", y = "Ozone", palette="Set2")
# Out:
# C:\Users\likhi\AppData\Local\Temp\ipykernel_19896\4024217822.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data1, x = "Weather", y = "Ozone", palette="Set2")
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# Out:
# C:\Users\likhi\AppData\Local\Temp\ipykernel_19896\1222012946.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange", palette="Set1", size=6, jitter = True)
# Out:
# C:\Users\likhi\AppData\Local\Temp\ipykernel_19896\489543265.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange", palette="Set1", size=6, jitter = True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="blue")
sns.rugplot(data=data1["Ozone"], color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="brown")
sns.rugplot(data=data1["Ozone"], color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %% [markdown]
# # Correlation coefficient and pair plots

# %%
plt.scatter(data1["Wind"], data1["Temp"])

# %%
data1["Wind"].corr(data1["Temp"])
# Out:
# -0.44122806925588215

# %% [markdown]
# ### observation
# - The correlation between wind and temp is observed to be negatively correlated with mild strength

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar    157 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 15.1+ KB

# %%
data1_numeric = data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar  Wind  Temp
# 0     41.0  190.0   7.4    67
# 1     36.0  118.0   8.0    72
# 2     12.0  149.0  12.6    74
# 3     18.0  313.0  11.5    62
# 4     31.0  199.0  14.3    56
# ..     ...    ...   ...   ...
# 152   20.0  223.0  11.5    68
# 153   41.0  190.0   7.4    67
# 154   30.0  193.0   6.9    70
# 155   31.0  145.0  13.2    77
# 157   18.0  131.0   8.0    76
#
# [157 rows x 4 columns]

# %%
data1_numeric.corr()
# Out:
#           Ozone     Solar      Wind      Temp
# Ozone  1.000000  0.297561 -0.523738  0.597087
# Solar  0.297561  1.000000 -0.057709  0.256994
# Wind  -0.523738 -0.057709  1.000000 -0.441228
# Temp   0.597087  0.256994 -0.441228  1.000000

# %% [markdown]
# ## Observations ##
# - The highest correlation strength is observed between Ozone and Temperature(0.597087)
# - The next higher correlation strength is observed between ozone and wind(-0.523738)
# - The next higher correlation strength is observed between wind and temp(-0.441228)
# - The least correlation strength is observed between solar and wind(-0.055874)

# %%
sns.pairplot(data1_numeric)

# %% [markdown]
# # Transformations

# %%
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0  190.0   7.4    1  2010    67       True      False      False
# 1     36.0  118.0   8.0    2  2010    72       True      False      False
# 2     12.0  149.0  12.6    3  2010    74       True      False      False
# 3     18.0  313.0  11.5    4  2010    62       True      False      False
# 4     31.0  199.0  14.3    5  2010    56       True      False      False
# ..     ...    ...   ...  ...   ...   ...        ...        ...        ...
# 152   20.0  223.0  11.5   30  2010    68      False      False      False
# 153   41.0  190.0   7.4    1  2010    67       True      False      False
# 154   30.0  193.0   6.9   26  2010    70      False      False      False
# 155   31.0  145.0  13.2   27  2010    77      False      False      False
# 157   18.0  131.0   8.0   29  2010    76      False      False      False
#
#      Month_8.0  Month_9.0  Weather_C  Weather_PS  Weather_S
# ...

# %%
data2=pd.get_dummies(data1,columns=['Month','Weather','Solar'])
data2
# Out:
#      Ozone  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  Month_8.0  \
# 0     41.0   7.4    1  2010    67       True      False      False      False
# 1     36.0   8.0    2  2010    72       True      False      False      False
# 2     12.0  12.6    3  2010    74       True      False      False      False
# 3     18.0  11.5    4  2010    62       True      False      False      False
# 4     31.0  14.3    5  2010    56       True      False      False      False
# ..     ...   ...  ...   ...   ...        ...        ...        ...        ...
# 152   20.0  11.5   30  2010    68      False      False      False      False
# 153   41.0   7.4    1  2010    67       True      False      False      False
# 154   30.0   6.9   26  2010    70      False      False      False      False
# 155   31.0  13.2   27  2010    77      False      False      False      False
# 157   18.0   8.0   29  2010    76      False      False      False      False
#
# ...

# %%
data2=pd.get_dummies(data1,columns=['Month','Weather','Solar','Ozone'])
data2
# Out:
#      Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  Month_8.0  \
# 0     7.4    1  2010    67       True      False      False      False
# 1     8.0    2  2010    72       True      False      False      False
# 2    12.6    3  2010    74       True      False      False      False
# 3    11.5    4  2010    62       True      False      False      False
# 4    14.3    5  2010    56       True      False      False      False
# ..    ...  ...   ...   ...        ...        ...        ...        ...
# 152  11.5   30  2010    68      False      False      False      False
# 153   7.4    1  2010    67       True      False      False      False
# 154   6.9   26  2010    70      False      False      False      False
# 155  13.2   27  2010    77      False      False      False      False
# 157   8.0   29  2010    76      False      False      False      False
#
#      Month_9.0  Weather_C  ...  Ozone_91.0  Ozone_96.0  Ozone_97.0  \
# ...
